# %%
# Import required packages
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup as soup
import selenium
from selenium import webdriver
from selenium.webdriver.common.by import By
import matplotlib.pyplot as plt
from sqlalchemy import *
# %matplotlib inline
import time

# %%
# Function that modifies baseball savant url for each team in order to get all batter data per date in 2019
def url_per_team(front_url, team, back_url):
    team_url = front_url + team + back_url
    return team_url

# %%
front_url = 'https://baseballsavant.mlb.com/statcast_search?hfPT=&hfAB=&hfBBT=&hfPR=&hfZ=&\
                stadium=&hfBBL=&hfNewZones=&hfGT=R%7C&hfC=&hfSea=2019%7C&hfSit=&player_type=batter&\
                hfOuts=&opponent=&pitcher_throws=&batter_stands=&hfSA=&game_date_gt=&game_date_lt=&\
                hfInfield=&team='

back_url = '&position=&hfOutfield=&hfRO=&home_road=&hfFlag=&hfPull=&metric_1=&hfInn=&min_pitches=0&\
                min_results=0&group_by=name-date&sort_col=ba&player_event_sort=h_launch_speed&\
                sort_order=desc&min_pas=0&chk_stats_pa=on&chk_stats_abs=on&chk_stats_hits=on&\
                chk_stats_singles=on&chk_stats_dbls=on&chk_stats_triples=on&chk_stats_hrs=on&\
                chk_stats_so=on&chk_stats_bb=on&chk_stats_ba=on&chk_stats_xba=on&chk_stats_xbadiff=on&\
                chk_stats_slg=on&chk_stats_xslg=on&chk_stats_xslgdiff=on#results'

teams = ['LAA', 'HOU', 'OAK', 'TOR', 'ATL', 'MIL', 'STL', 'CHC', 'ARI', 'LAD', 'SF', 'CLE', 'SEA', \
            'MIA', 'NYM', 'WSH', 'BAL', 'SD', 'PHI', 'PIT', 'TEX', 'TB', 'BOS', 'CIN', 'COL', 'KC', \
            'DET', 'MIN', 'CWS', 'NYY']

# %%
team_urls = []

for team in teams:
    team_url = url_per_team(front_url, team, back_url)
    team_urls.append(team_url)

# %%
# csv_button = driver.
# csv_button.click()

# %%
# Create a function that takes a url to download mlb team batting stats
def scrape_team(url):
    # Selenium functions to scrape data from a specified URL
    path_to_chromedriver = './chromedriver' # Path to access a chrome driver
    browser = webdriver.Chrome(executable_path=path_to_chromedriver)
    browser.get(url)
#     table = browser.find_element_by_class_name('nba-stat-table__overflow')
    submit_button = driver.find_elements_by_xpath('<span title="Download Data as Comma Separated Values File" class="table-icon csv" id="csv_all_pid_"><img src="site-core/images/database_link.png"></span>')[0]
    submit_button.click()

# %%
# scrape_team(team_urls[0])

# %%
path_to_chromedriver = './chromedriver' # Path to access a chrome driver
driver = webdriver.Chrome(executable_path=path_to_chromedriver)
driver.get(team_urls[0])


# xp = '/html/body/div[4]/div[1]/div/div/div[4]/\
#             table/thead/tr/th[7]/div/span[2]'

# xp_elem = driver.find_elements_by_xpath(xp)

# classname = 'table-icon csv_table'
# class_elem = driver.find_elements_by_class_name(classname)

eyed = 'table_all_pid_'
id_elem = driver.find_elements_by_id(eyed)
id_elem[0].click()

# eyed = driver.find_element(By.ID, 'eyed')
# eyed = eyed.find_elements_by_id("'eyed'")

# %%
xp_elem, class_elem, id_elem
# Out:
# ([],
#  [],
#  [<selenium.webdriver.remote.webelement.WebElement (session="4ac38d4500d088dcfa2c5f9108070c3b", element="0ed2f7dc-5100-4add-a6be-6e0acb7d6a87")>])

# %%
img = driver.find_elements_by_xpath('//*[@id="table_all_pid_"]')
img[0].click()

# %%
search_results = driver.find_elements_by_id('search_results')
search_results.
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="4ac38d4500d088dcfa2c5f9108070c3b", element="1d35356c-55d4-4863-b4ca-b847cc47f382")>]

# %%
path_to_chromedriver = './chromedriver' # Path to access a chrome driver
driver = webdriver.Chrome(executable_path=path_to_chromedriver)
driver.get(team_urls[0])

# %%
player = driver.find_elements_by_class_name('player_name')
player
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="50971ebbdace81ddb98a8d310806ce84", element="6389f3a5-6ff9-4915-a6b5-f430675613af")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="50971ebbdace81ddb98a8d310806ce84", element="3111e7a5-f2cd-489d-8045-6b56cbae342c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="50971ebbdace81ddb98a8d310806ce84", element="573cc62f-7727-497b-ab80-9d68ac347a49")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="50971ebbdace81ddb98a8d310806ce84", element="9bc5ad2e-06d3-4a48-aacc-c9b61d3b063f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="50971ebbdace81ddb98a8d310806ce84", element="303f5de5-2fed-40e0-88a8-e213735b66b4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="50971ebbdace81ddb98a8d310806ce84", element="3193259f-2efa-4855-91e9-0bfd99423901")>,
# ...

# %%
for p in player:
    p.click()
# Out:
# ---------------------------------------------------------------------------
# ElementClickInterceptedException          Traceback (most recent call last)
# <ipython-input-87-422c80647573> in <module>
#       1 for p in player:
# ----> 2     p.click()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webelement.py in click(self)
#      78     def click(self):
#      79         """Clicks the element."""
# ---> 80         self._execute(Command.CLICK_ELEMENT)
#      81
#      82     def submit(self):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#     635     def find_element(self, by=By.ID, value=None):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
# ...

# %%
laa = pd.read_csv('https://baseballsavant.mlb.com/statcast_search/csv?all=true&hfPT=&hfAB=&hfBBT=&hfPR=&hfZ=&stadium=&hfBBL=&hfNewZones=&hfGT=R%7C&hfC=&hfSea=2019%7C&hfSit=&player_type=batter&hfOuts=&opponent=&pitcher_throws=&batter_stands=&hfSA=&game_date_gt=&game_date_lt=&hfInfield=&team=LAA&position=&hfOutfield=&hfRO=&home_road=&hfFlag=&hfPull=&metric_1=&hfInn=&min_pitches=0&min_results=0&group_by=name&sort_col=pitches&player_event_sort=h_launch_speed&sort_order=desc&min_pas=0&')

# %%
laa
# Out:
#     pitches  player_id         player_name  total_pitches  pitch_percent  \
# 0      2629     664058      David Fletcher           2629          100.0
# 1      2509     545361          Mike Trout           2509          100.0
# 2      2389     594777        Kole Calhoun           2389          100.0
# 3      2085     405395       Albert Pujols           2085          100.0
# 4      1979     571718       Brian Goodwin           1979          100.0
# 5      1683     660271       Shohei Ohtani           1683          100.0
# 6      1669     650859        Luis Rengifo           1669          100.0
# 7      1389     592743   Andrelton Simmons           1389          100.0
# 8      1209     600303     Tommy La Stella           1209          100.0
# 9      1129     457708        Justin Upton           1129          100.0
# 10     1126     518960     Jonathan Lucroy           1126          100.0
# 11      797     607345         Kevan Smith            797          100.0
# ...

# %%
laa_batters = 'https://baseballsavant.mlb.com/statcast_search/csv?all=true&\
        hfPT=&hfAB=&hfBBT=&hfPR=&hfZ=&stadium=&hfBBL=&hfNewZones=&hfGT=R%7C&hfC=&hfSea=2019%7C&\
        hfSit=&player_type=batter&hfOuts=&opponent=&pitcher_throws=&batter_stands=&hfSA=&\
        game_date_gt=&game_date_lt=&hfInfield=&team=LAA&position=&hfOutfield=&hfRO=&\
        home_road=&hfFlag=&hfPull=&metric_1=&hfInn=&min_pitches=0&min_results=0&\
        group_by=name-date&sort_col=ba&player_event_sort=h_launch_speed&sort_order=desc&\
        min_pas=0&chk_stats_pa=on&chk_stats_abs=on&chk_stats_hits=on&chk_stats_singles=on&\
        chk_stats_dbls=on&chk_stats_triples=on&chk_stats_hrs=on&chk_stats_so=on&\
        chk_stats_k_percent=on&chk_stats_bb=on&chk_stats_bb_percent=on&chk_stats_babip=on&\
        chk_stats_iso=on&chk_stats_ba=on&chk_stats_xba=on&chk_stats_xbadiff=on&chk_stats_slg=on&\
        chk_stats_xslg=on&chk_stats_xslgdiff=on&chk_stats_woba=on&chk_stats_xwoba=on&chk_stats_wobadiff=on&'

# %%
laa = pd.read_csv(laa_batters)

# %%
laa
# Out:
#       pitches  player_id    player_name   game_date  total_pitches  \
# 0           5     405395  Albert Pujols  2019-04-13              5
# 1           5     621493    Taylor Ward  2019-07-23              5
# 2           5     571718  Brian Goodwin  2019-08-24              5
# 3           8     405395  Albert Pujols  2019-05-20              8
# 4           5     660271  Shohei Ohtani  2019-07-24              5
# ...       ...        ...            ...         ...            ...
# 1600       18     594777   Kole Calhoun  2019-07-06             18
# 1601        3     665120    Jared Walsh  2019-09-11              3
# 1602       19     594777   Kole Calhoun  2019-07-12             19
# 1603       10     665120    Jared Walsh  2019-09-10             10
# 1604       15     665120    Jared Walsh  2019-09-06             15
#
#       pitch_percent   ba  iso  babip  slg  ...  takes  eff_min_vel  \
# 0             100.0  NaN  NaN    NaN  NaN  ...      5         -1.1
# ...
