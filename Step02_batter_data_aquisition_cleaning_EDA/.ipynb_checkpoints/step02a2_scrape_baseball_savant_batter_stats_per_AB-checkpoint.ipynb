# %%
# Import required packages
import pandas as pd
import numpy as np
# %matplotlib inline
import time

# %%
# Function that modifies baseball savant url for each team in order to get all batter data per date in 2019
def url_per_team(front_url, team, back_url):
    team_url = front_url + team + back_url
    team_url = team_url.replace(' ', '')
    return team_url

# %%
front_url = 'https://baseballsavant.mlb.com/statcast_search/csv?all=true&\
                hfPT=&hfAB=single%7Cdouble%7Ctriple%7Chome%5C.%5C.run%7Cfield%5C.%5C.out%7Cstrikeout%\
                7Cstrikeout%5C.%5C.double%5C.%5C.play%7Cwalk%7Cdouble%5C.%5C.play%7Cfield%5C.%\
                5C.error%7Cgrounded%5C.%5C.into%5C.%5C.double%5C.%5C.play%7Cfielders%5C.%5C.choice%\
                7Cfielders%5C.%5C.choice%5C.%5C.out%7Cbatter%5C.%5C.interference%7Ccatcher%5C.%5C.interf%\
                7Ccaught%5C.%5C.stealing%5C.%5C.2b%7Ccaught%5C.%5C.stealing%5C.%5C.3b%7Ccaught%5C.%5C.stealing%\
                5C.%5C.home%7Cforce%5C.%5C.out%7Chit%5C.%5C.by%5C.%5C.pitch%7Cintent%5C.%5C.walk%7Csac%5C.%\
                5C.bunt%7Csac%5C.%5C.bunt%5C.%5C.double%5C.%5C.play%7Csac%5C.%5C.fly%7Csac%5C.%5C.fly%5C.%\
                5C.double%5C.%5C.play%7Ctriple%5C.%5C.play%7C&hfBBT=&hfPR=&hfZ=&stadium=&hfBBL=&hfNewZones=&\
                hfGT=R%7C&hfC=&hfSea=2019%7C&hfSit=&player_type=batter&hfOuts=&opponent=&pitcher_throws=&\
                batter_stands=&hfSA=&game_date_gt=&game_date_lt=&hfInfield=&team='


back_url = '&position=&hfOutfield=&hfRO=&home_road=&hfFlag=&\
                hfPull=&metric_1=&hfInn=&min_pitches=0&min_results=0&\
                group_by=name-date&sort_col=pitches&player_event_sort=h_launch_speed&sort_order=desc&\
                min_pas=0&chk_stats_pa=on&chk_stats_abs=on&chk_stats_hits=on&chk_stats_singles=on&\
                chk_stats_dbls=on&chk_stats_triples=on&chk_stats_hrs=on&chk_stats_so=on&\
                chk_stats_k_percent=on&chk_stats_bb=on&chk_stats_bb_percent=on&chk_stats_babip=on&\
                chk_stats_iso=on&chk_stats_ba=on&chk_stats_xba=on&chk_stats_xbadiff=on&chk_stats_slg=on&\
                chk_stats_xslg=on&chk_stats_xslgdiff=on&chk_stats_woba=on&chk_stats_xwoba=on&\
                chk_stats_wobadiff=on&type=details&'

teams = ['LAA', 'HOU', 'OAK', 'TOR', 'ATL', 'MIL', 'STL', 'CHC', 'ARI', 'LAD', 'SF', 'CLE', 'SEA', \
            'MIA', 'NYM', 'WSH', 'BAL', 'SD', 'PHI', 'PIT', 'TEX', 'TB', 'BOS', 'CIN', 'COL', 'KC', \
            'DET', 'MIN', 'CWS', 'NYY']

# %%
# Create dictionary of team names and baseaball savant urls

team_urls_dict = {}

for team in teams:
    name_lower = team.lower()
    team_url = url_per_team(front_url, team, back_url)
    team_urls_dict.update({name_lower: team_url})

# %%
# Check to see if dictionary works and it does
team_urls_dict['pit'];

# %%
# Test scrape for LA Angels batter data and it works!

# laa = pd.read_csv(team_urls_dict['laa'])
# laa

# %%
# Create a function that takes a team name and url
# It captues csv batter data for that team
# Adds a column with the team name
# Saves df to a dataframe
# It returns the team id (lowercase) and the batters data dataframe dictionary

def get_batters_data(team, url):
    batter_df = pd.read_csv(url)
    batter_df['team'] = team
    return team, batter_df

# %%
# Create dictionary with which to save all batter dataframes acquired from baseball savant
batter_df_dict = {}
teams_left = 29

for team in team_urls_dict:  
    team, batter_df = get_batters_data(team, team_urls_dict[team])
    batter_df_dict.update({team: batter_df})
    print('Just snagged batter data for {}, {} of 30 teams left...'.format(team, teams_left))
    teams_left -= 1
    time.sleep(20)
    
# After snagging data for half the league (15 teams) hit a 502 error
# Disabling code so webscraping does not rerun
# Out:
# Just snagged batter data for laa
# Just snagged batter data for hou
# Just snagged batter data for oak
# Just snagged batter data for tor
# Just snagged batter data for atl
# Just snagged batter data for mil
# Just snagged batter data for stl
# Just snagged batter data for chc
# Just snagged batter data for ari
# Just snagged batter data for lad
# Just snagged batter data for sf
# Just snagged batter data for cle
# Just snagged batter data for sea
# Just snagged batter data for mia
# Just snagged batter data for nym
# Just snagged batter data for wsh
# Just snagged batter data for bal
# Just snagged batter data for sd
# Just snagged batter data for phi
# Just snagged batter data for pit
# Just snagged batter data for tex
# Just snagged batter data for tb
# Just snagged batter data for bos
# Just snagged batter data for cin
# Just snagged batter data for col
# Just snagged batter data for kc
# Just snagged batter data for det
# Just snagged batter data for min
# Just snagged batter data for cws
# Just snagged batter data for nyy

# %%
# New loop to grab teams not acquired prior to the 502 error thrown above

for team in team_urls_dict:
    if team in batter_df_dict:
        print('Skipping {}, already grabbed it'.format(team))
    else:
        team, batter_df = get_batters_data(team, team_urls_dict[team])
        batter_df_dict.update({team: batter_df})
        print('Just snagged batter data for {}'.format(team))
        time.sleep(20)
# Out:
# Skipping laa, already grabbed it
# Skipping hou, already grabbed it
# Skipping oak, already grabbed it
# Skipping tor, already grabbed it
# Skipping atl, already grabbed it
# Skipping mil, already grabbed it
# Skipping stl, already grabbed it
# Skipping chc, already grabbed it
# Skipping ari, already grabbed it
# Skipping lad, already grabbed it
# Skipping sf, already grabbed it
# Skipping cle, already grabbed it
# Skipping sea, already grabbed it
# Skipping mia, already grabbed it
# Skipping nym, already grabbed it
# Skipping wsh, already grabbed it
# Skipping bal, already grabbed it
# Skipping sd, already grabbed it
# Skipping phi, already grabbed it
# Skipping pit, already grabbed it
# Skipping tex, already grabbed it
# Skipping tb, already grabbed it
# Skipping bos, already grabbed it
# Skipping cin, already grabbed it
# Skipping col, already grabbed it
# Skipping kc, already grabbed it
# Skipping det, already grabbed it
# Skipping min, already grabbed it
# Skipping cws, already grabbed it
# Skipping nyy, already grabbed it

# %%
batter_df_dict['cws']
# Out:
#      pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0            SI  2019-09-29           94.5        -3.0361         5.4109
# 1            SI  2019-09-29           90.8        -3.0485         5.3155
# 2            SI  2019-09-29           94.1        -3.1220         5.4569
# 3            CU  2019-09-29           80.2        -3.6980         4.3751
# 4            FT  2019-09-29           93.6        -3.6417         4.6661
# ...         ...         ...            ...            ...            ...
# 6031         SL  2019-03-28           86.0        -1.8296         6.1711
# 6032         FF  2019-03-28           93.5        -1.5122         6.1863
# 6033         FT  2019-03-28           93.3        -1.7206         6.1358
# 6034         FT  2019-03-28           93.4        -1.6862         6.1232
# 6035         FT  2019-03-28           95.5        -1.6533         6.1996
#
#          player_name  batter  pitcher                     events  \
# 0       Eloy Jimenez  650391   622505  grounded_into_double_play
# 1       Yoan Moncada  660162   622505               hit_by_pitch
# 2         Ryan Goins  572365   622505                  field_out
# 3      Danny Mendick  664901   670167                  strikeout
# 4     Yolmer Sanchez  570560   670167                  strikeout
# ...              ...     ...      ...                        ...
# 6031    Eloy Jimenez  650391   641745                  strikeout
# 6032   Yonder Alonso  475174   641745                  field_out
# 6033      Jose Abreu  547989   641745                  field_out
# 6034    Yoan Moncada  660162   641745                  field_out
# 6035    Leury Garcia  544725   641745                  field_out
#
#                   description  ...  away_score  bat_score  fld_score  \
# 0               hit_into_play  ...           2          5          2
# 1                hit_by_pitch  ...           2          5          2
# 2               hit_into_play  ...           2          5          2
# 3             swinging_strike  ...           2          5          2
# 4             swinging_strike  ...           2          5          2
# ...                       ...  ...         ...        ...        ...
# 6031  swinging_strike_blocked  ...           0          0          0
# 6032            hit_into_play  ...           0          0          0
# 6033            hit_into_play  ...           0          0          0
# 6034            hit_into_play  ...           0          0          0
# 6035            hit_into_play  ...           0          0          0
#
#       post_away_score  post_home_score post_bat_score post_fld_score  \
# 0                   2                5              5              2
# 1                   2                5              5              2
# 2                   2                5              5              2
# 3                   2                5              5              2
# 4                   2                5              5              2
# ...               ...              ...            ...            ...
# 6031                0                0              0              0
# 6032                0                0              0              0
# 6033                0                0              0              0
# 6034                0                0              0              0
# 6035                0                0              0              0
#
#      if_fielding_alignment of_fielding_alignment team
# 0                 Standard              Standard  cws
# 1                 Standard              Standard  cws
# 2            Infield shift              Standard  cws
# 3                 Standard              Standard  cws
# 4                 Standard              Standard  cws
# ...                    ...                   ...  ...
# 6031         Infield shift              Standard  cws
# 6032         Infield shift             Strategic  cws
# 6033              Standard              Standard  cws
# 6034         Infield shift              Standard  cws
# 6035              Standard              Standard  cws
#
# [6036 rows x 90 columns]

# %%
# Loop through batter_df_dict and concatitate all dfs into one master file

for team in batter_df_dict.keys():
    if team == 'laa':
        all_batters_df = batter_df_dict[team]
    else:
        all_batters_df = pd.concat([all_batters_df, batter_df_dict[team]])

# %%
# Looks good, let's save as a csv and continue working in the next notebook
all_batters_df.to_csv('../data/processed/2019_batter_data_by_ab.csv')
